# %%
import pandas

# %%
inputs = pandas.read_csv('inputs.csv',names=['id','tx_id','output_id'])
outputs = pandas.read_csv('outputs.csv',names=['id','tx_id','pk_id','value'])
transactions = pandas.read_csv('transactions.csv',names=['id','block_id','is_coinbase'])

# %%
transactions.head(200)
# Out:
#       id  block_id  is_coinbase
# 0      1         0            1
# 1      2         1            1
# 2      3         2            1
# 3      4         3            1
# 4      5         4            1
# 5      6         5            1
# 6      7         6            1
# 7      8         7            1
# 8      9         8            1
# 9     10         9            1
# 10    11        10            1
# 11    12        11            1
# 12    13        12            1
# 13    14        13            1
# 14    15        14            1
# 15    16        15            1
# 16    17        16            1
# 17    18        17            1
# 18    19        18            1
# 19    20        19            1
# 20    21        20            1
# 21    22        21            1
# 22    23        22            1
# 23    24        23            1
# 24    25        24            1
# 25    26        25            1
# 26    27        26            1
# 27    28        27            1
# ...

# %%
transactions.head(172)
# Out:
#       id  block_id  is_coinbase
# 0      1         0            1
# 1      2         1            1
# 2      3         2            1
# 3      4         3            1
# 4      5         4            1
# 5      6         5            1
# 6      7         6            1
# 7      8         7            1
# 8      9         8            1
# 9     10         9            1
# 10    11        10            1
# 11    12        11            1
# 12    13        12            1
# 13    14        13            1
# 14    15        14            1
# 15    16        15            1
# 16    17        16            1
# 17    18        17            1
# 18    19        18            1
# 19    20        19            1
# 20    21        20            1
# 21    22        21            1
# 22    23        22            1
# 23    24        23            1
# 24    25        24            1
# 25    26        25            1
# 26    27        26            1
# 27    28        27            1
# ...

# %%
import numpy as np
from numpy import genfromtxt

inputs = genfromtxt('inputs.csv', delimiter=',', dtype='int')
outputs = genfromtxt('outputs.csv', delimiter=',', dtype='int')
transactions = genfromtxt('transactions.csv', delimiter=',', dtype='int')

utxo = []

temp_block = 0
temp_coinbase = False
#loops through all transactions
for row in transactions:
	#different block
	if temp_block != row[1]:
		if row[1] != temp_block + 1:
			print("Invalid Block! Block # %d doesn't exist." % (temp_block + 1))
		temp_block = row[1]
		temp_coinbase = False

	#check if coinbase
	if (row[2] == 1):
		if temp_coinbase:
			print("Invalid Block! Multiple coinbase transactions for block # %d" % row[1])
		else:
			temp_coinbase = True
			
			#need to keep track of value of the transaction from outputs file
			utxo.append(row)
	else:
		if not temp_coinbase:
			print("Invalid Block! No coinbase transaciton for block # %d" %row[1])
		#need to find which previous tx this tx is part of
# Out:
# Invalid Block! Multiple coinbase transactions for block # 52534
# Invalid Block! Block # 91857 doesn't exist.
